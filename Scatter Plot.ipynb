# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#I got this data from SDA KIDS AND AGE downloads
df = pd.read_csv('sub-data.csv')
df.head()

x = 'KIDS'
y = 'AGE'

plt.scatter(x = df[x], y = df[y], s = 1)
plt.title('Amount of kids by age of head of household')
plt.xlabel('Total number of children in household ')#x axis is number of children in household
plt.ylabel(' Age of head of household      ')#y axis is age of head of household
# Out:
# Text(0, 0.5, ' Age of head of household      ')
